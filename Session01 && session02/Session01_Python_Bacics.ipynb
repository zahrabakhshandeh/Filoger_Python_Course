# %% [markdown]
# ### Session 01 (Basic)

# %%
length = 20
width = 12
area = length * width
environment = (length + width) * 2
print(area, environment)
# Out:
# 180 54

# %% [markdown]
# ### var

# %%
### var name
x1 = 10
x = 20

# %%
a = 12
b = 19
c = 15
d = 12
e = 20
print(a, b, c, d, e)
# Out:
# 12 19 15 12 20

# %%
math = 12
python = 17
fistnumber = 12

# %%
## camelCase
fistNumber = 12
## PascalCase
FistNumber = 12
Math = 14
## snake_case 
fist_number = 12

# %% [markdown]
# ### var Type

# %%
number1 = 12
number2 = 14.5
## integer(int), float, string(str), boolean(bool)

# %%
## int
number3 = 12

# %%
## float
number4 = 12.7

# %%
## str
name = '123'
print(name)
# Out:
# 123

# %%
## bool
flag1 = True
flag2 = False
print(flag1, flag2)
# Out:
# True False

# %%
num1 = 20   # int
num2 = 23. # float
name = "sara"
flag = True
## type()
t1 = type(flag)
print(t1)
# Out:
# <class 'bool'>

# %%
x = 10
t1 = type(x)
print(t1)
x = 20.3
print(type(x))
# Out:
# <class 'int'>
# <class 'float'>

# %%
x = 13
y = 12
y = x
print(y)
# Out:
# 13

# %%
## int, float
## +, -, *, /, **, //, %
num1 = 12
num2 = 7.3
print(num1 ** 3)
print(num1 / 5)
print(num1 // 5)
print(num1 % 5)
# Out:
# 1728
# 2.4
# 2
# 2

# %%
## >, <, >=, <=, ==, !=   =====> res : bool
num1 = 20
num2 = 20
print(num1 >= num2)
print(num1 == num2)
print(num1 != num2)
# Out:
# True
# True
# False

# %%
# or, and
num1 = 20
num2 = 30
num3 = 39
#         True    and     False   and    True
print(num2 > num1 and num2 > num3 and num3 > num1)
print(num2 > num1 or num2 > num3 or num3 > num1)
# Out:
# False
# True

# %%
num1 = 10
num2 = 15
num3 = 20
print(num1 < num2 and num2 < num3)
# Out:
# True

# %%
num = "12"
#print(num + 2)

# %% [markdown]
# ### Casting

# %%
## int()
num = "12"
print(type(num))
num = int(num) #  int("12") ===> 12
print(type(num))
print(num + 2)
# Out:
# <class 'str'>
# <class 'int'>
# 14

# %%
num = "python"
#num = int(num)

# %%
num = "12.4"
num = int(num)
print(num)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_17416/2545763349.py in <module>
#       1 num = "12.4"
# ----> 2 num = int(num)
#       3 print(num)
#
# ValueError: invalid literal for int() with base 10: '12.4'

# %%
num = 12.4
num = int(num)
print(num)
# Out:
# 12

# %%
flag1 = True
flag2 = False
flag1 = int(flag1)
flag2 = int(flag2)
print(flag1, flag2)
# Out:
# 1 0

# %%
## float
num = 10
num = float(num)
print(num)
# Out:
# 10.0

# %%
num = "12"
num = float(num)
print(num)
# Out:
# 12.0

# %%
num = "12.4"
num = float(num)
print(num)
# Out:
# 12.4

# %%
flag1 = True
flag2 = False
flag1 = float(flag1)
flag2 = float(flag2)
print(flag1, flag2)
# Out:
# 1.0 0.0

# %%
## str()
num1 = 12
num2 = 2.3
flag = True
num1 = str(num1)
num2 = str(num2)
flag = str(flag)
print(num1, num2, type(flag))
# Out:
# 12 2.3 <class 'str'>

# %%
## bool()
# False, 0, "", 0.0
num = -10
num = bool(num)
print(num)
# Out:
# True

# %%
num = False
num = int(num)
print(num)
# Out:
# 0

# %%
python = 12
name = "1456"
print(name)
num1 = 10
num2 = 15
print(num1 != num2)
# Out:
# 1456
# True

# %%
## 0, 0.0, False, ""
var1 = False
var1 = bool(var1)
print(var1)

# %%
num = "12.4"
num = float(num)
num = int(num)
print(num)
# Out:
# 12

# %% [markdown]
# ### input

# %%
## input() =====> str
num1 = float(input("your number1: "))
num2 = float(input("your number2: "))
#num1 = int(num1)
#num2 = int(num2)
res = num1 + num2
print(res)
# Out:
# 14.9

# %%
num1 = 20  
num2 = 30
temp = num1 # temp = 20
num1 = num2  # num1 = 30
num2 = temp # num2 = 20
print(num1, num2)
# Out:
# 30 20
